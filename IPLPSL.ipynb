# %%
import json

dataPath = '/Users/Intern/Documents/Py/iplpsl_data.txt'

tweetsData = []
tweetsFileData = open(dataPath, 'r')

# %% [markdown]
# We import json library and define our data path. Then we read the path data into tweets variable

# %%
for line in tweetsFileData:
    try: 
        tweet = json.loads(line)
        tweetsData.append(tweet)
    except:
        continue

print len(tweetsData)
print(dir(tweetsData[0]))
# Out:
# 8009
# ['__class__', '__cmp__', '__contains__', '__delattr__', '__delitem__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'has_key', 'items', 'iteritems', 'iterkeys', 'itervalues', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values', 'viewitems', 'viewkeys', 'viewvalues']

# %% [markdown]
# We read our file data into tweetData variable line by line. Then we print our tweetsData length to show number of tweets we have in it.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys

# %%
tweets = pd.DataFrame()

tweets['likes'] = [tweet['user']['favourites_count']if "user" in tweet and tweet['user'] else np.nan for tweet in tweetsData ]
tweets['friends'] = [tweet['user']['friends_count']if "user" in tweet and tweet['user'] else np.nan for tweet in tweetsData ]
tweets['followers'] = [tweet['user']['followers_count']if "user" in tweet and tweet['user'] else np.nan for tweet in tweetsData ]
tweets['statuses'] = [tweet['user']['statuses_count']if "user" in tweet and tweet['user'] else np.nan for tweet in tweetsData ]
# tweets['favorites'] = [tweet['user']['favourites_count']if "user" in tweet and tweet['user'] else np.nan for tweet in tweets_data ]
tweets['createdAt'] = [tweet['user']['created_at']if "user" in tweet and tweet['user'] else np.nan for tweet in tweetsData ]

# tweets['retweet'] = map(lambda tweet: tweet.get('retweet_count', None),tweetsData)
tweets['text'] = map(lambda tweet: tweet.get('text', None),tweetsData)
tweets['lang'] = map(lambda tweet: tweet.get('lang', None),tweetsData)
tweets['source'] = map(lambda tweet: tweet.get('source', None),tweetsData)
tweets['country'] = [tweet['place']['country']if "place" in tweet and tweet['place'] else np.nan for tweet in tweetsData ]

tweets.index
# Out:
# RangeIndex(start=0, stop=8009, step=1)

# %% [markdown]
# We create a dataFrame called tweets and assign to it's column json values. Then we show how our data is indexed by pandas library.

# %%
display(tweets.head(10))
display(tweets.tail(5))
tweets.describe()
# Out:
#    likes  friends  followers  statuses                       createdAt  \
# 0   1176      252         24      1337  Wed Jun 18 20:48:43 +0000 2014
# 1  64060     1238        635      8049  Fri Oct 14 09:31:05 +0000 2011
# 2     27      353         52      5472  Tue Apr 11 22:11:27 +0000 2017
# 3  30144     1721       2489     10433  Wed Feb 22 21:50:07 +0000 2017
# 4  18144      118        305      7304  Sun Aug 17 08:39:38 +0000 2014
# 5  10093      316        322     13922  Thu May 28 16:01:12 +0000 2015
# 6  17611      340       4428     20080  Tue May 03 12:42:49 +0000 2011
# 7     89       77         35       334  Thu Oct 27 17:21:51 +0000 2011
# 8  38677     1157        623     26219  Mon Aug 07 04:31:57 +0000 2017
# 9   2950     1084        238      2803  Tue Feb 27 11:08:40 +0000 2018
#
#                                                 text lang  \
# 0  @TomaszGolubski @KosiniakKamysz @nowePSL @Mlod...   pl
# 1  Everyone is celebrating PSL final but you know...   en
# ...

# %% [markdown]
# Displaying first 10 rows of our data and last 5 rows. Then a summarization of our data is presented, it shows us following statistical data:
# 1) Count of all likes
# 2) mean of likes
# 3) standard deviation of likes
# 4) minimum number of likes on a tweet
# 5) Maximum number of likes on a tweet
# 6) Percentiles (25%, 50%, 75%)

# %%
rows,columns = tweets.shape
print rows, columns

tweets[tweets.likes == tweets['likes'].min()]
# Out:
# 8009 9
#       likes  friends  followers  statuses                       createdAt  \
# 72        0       31          1       126  Wed Aug 10 11:44:29 +0000 2016
# 74        0        0          0        66  Sat Mar 10 15:44:34 +0000 2018
# 85        0        0          0        67  Sat Mar 10 15:44:34 +0000 2018
# 98        0        0          0        68  Sat Mar 10 15:44:34 +0000 2018
# 114       0        0          0        69  Sat Mar 10 15:44:34 +0000 2018
# 129       0        0          0        70  Sat Mar 10 15:44:34 +0000 2018
# 143       0        6          9      6794  Mon Dec 28 06:10:11 +0000 2015
# 144       0        4         34      1132  Tue Feb 23 10:52:07 +0000 2016
# 203       0        0       1658      4774  Sat Aug 27 08:29:39 +0000 2016
# 204       0       84          4       800  Fri Nov 17 01:26:45 +0000 2017
# 208       0      105         11      1243  Tue Jan 30 05:40:14 +0000 2018
# 279       0        6        901     74017  Tue Feb 05 15:52:03 +0000 2013
# ...

# %%
tweets[tweets.likes == tweets['likes'].max()]
# Out:
#                             likes  friends  followers  statuses  \
# date
# 2010-01-28 12:29:43+00:00  522948     4985       3876    220174
#
#                                                 createdAt  \
# date
# 2010-01-28 12:29:43+00:00  Thu Jan 28 12:29:43 +0000 2010
#
#                                                                         text  \
# date
# 2010-01-28 12:29:43+00:00  @AasthaVarma @yadavakhilesh @BJP4India @IPL @r...
#
#                           lang  \
# date
# 2010-01-28 12:29:43+00:00   en
#
#                                                                       source  \
# date
# 2010-01-28 12:29:43+00:00  <a href="http://twitter.com/download/iphone" r...
#
#                           country
# date
# 2010-01-28 12:29:43+00:00     NaN

# %% [markdown]
# This shows that we have 8009 rows and 9 columns for our dataframe and we have 501 tweets with minimum number of likes. While only a single tweet exist with maximum number of likes. This show that average User Engagement with IPL and PSL tweets, lies close to minimum number of likes as only 500 minimum number of likes tweet exist

# %%
tweets[tweets.likes <= 1000]
# Out:
#                            likes  friends  followers  statuses  \
# date
# 2017-04-11 22:11:27+00:00     27      353         52      5472
# 2011-10-27 17:21:51+00:00     89       77         35       334
# 2014-06-05 11:32:52+00:00    146       25         41       211
# 2018-02-21 18:40:35+00:00    350       74         52       770
# 2018-03-19 09:29:33+00:00     44       41          1        26
# 2009-01-30 14:56:22+00:00    746      157        175      2217
# 2014-06-05 11:32:52+00:00    147       25         41       212
# 2018-03-19 19:28:11+00:00     64      172         31       472
# 2018-01-11 19:02:31+00:00    237      897        889       626
# 2017-11-22 07:42:46+00:00     12      122         19       470
# 2012-11-25 13:43:16+00:00    672       99         68      1605
# 2018-03-25 11:35:19+00:00      2       23          2         3
# 2016-06-17 23:54:46+00:00    518      206        441      1771
# 2014-12-20 12:21:13+00:00    471      306       1112     22004
# ...

# %% [markdown]
# It shows that 5243 tweets have above than 1000 likes. This proves our above observation that majority of the tweet's user engagement lies in between max and min but nearer to min.

# %% [markdown]
# Observe top 7 languages for IPL PSL tweets

# %%
tweetsLanguage = tweets['lang'].value_counts()

fig, ax = plt.subplots()
ax.tick_params(axis = 'x', labelsize = 15)
ax.tick_params(axis = 'y', labelsize = 10)
ax.set_xlabel('Languages', fontSize = 10)
ax.set_ylabel('Number Of Tweets', fontsize = 10)
ax.set_title('Top 7 languages', fontsize= 20, fontweight = 'bold')
tweetsLanguage[:7].plot(ax=ax, kind = 'bar', color = 'blue')

# %% [markdown]
# Tweets are tweeted by following language order:
# 1) English
# 2) Urdu
# 3) Indonesian
# 4) Hindi
# 5) Undefiend
# 6) Tagalog
# 7) Polish
# This shows user orientation in terms of countries. Most languages belong to South Asian Countries, English being top rated as it's second popular language in Pakistan and India. English is followed by Urdu. This shows that most tweeps are of Pakistani and Indian origin
#
# Let's now observe counrties

# %%
tweetsLanguage = tweets['country'].value_counts()

fig, ax = plt.subplots()
ax.tick_params(axis = 'x', labelsize = 15)
ax.tick_params(axis = 'y', labelsize = 10)
ax.set_xlabel('Countries', fontSize = 10)
ax.set_ylabel('Number Of Tweets', fontsize = 10)
ax.set_title('Top 7 Countries', fontsize= 20, fontweight = 'bold')
tweetsLanguage[:7].plot(ax=ax, kind = 'bar', color = 'blue')

# %% [markdown]
# Above state is proved as we see Pakistan and India being top countries of tweeps. South Asia, Middle East, Europe and North America being top 4 continents.

# %%
newTweets = tweets.groupby('country')
newTweets.describe()
# Out:
#                             followers                                       \
#                                 count          mean           std      min
# country
# Australia                         2.0    359.500000    120.915260    274.0
# Bahrain                           1.0     47.000000           NaN     47.0
# India                            28.0   6082.464286  24188.282785      0.0
# Kingdom of Saudi Arabia           3.0    137.666667    103.871716     47.0
# Malaysia                          5.0    596.400000    649.006009     41.0
# Pakistan                         52.0   3409.807692  11099.762236      2.0
# Republic of the Philippines       1.0   1133.000000           NaN   1133.0
# Russia                            2.0    413.000000    241.830519    242.0
# Singapore                         3.0   1099.666667   1667.970124     68.0
# South Africa                      4.0  16258.750000  18246.289255     62.0
# ...

# %% [markdown]
# This shows us our data by counrties. Though it's not the most visualizing of formats. We see individual countries by below, but it only represents some of the data

# %%
newTweets.get_group('Pakistan')
# Out:
#                            createdAt  followers  friends lang  likes  \
# 173   Wed Feb 15 09:48:39 +0000 2012         13      178   en    765
# 189   Thu Oct 14 21:53:20 +0000 2010      75307      455   en   9503
# 218   Tue Oct 18 16:55:21 +0000 2011         71     1426   en      8
# 473   Tue Jun 10 21:26:50 +0000 2014        191      521   ur  10023
# 558   Tue Oct 16 20:46:23 +0000 2012        618       69   en   5362
# 681   Tue Oct 16 20:46:23 +0000 2012        618       69   en   5362
# 746   Tue Oct 24 12:05:56 +0000 2017          4       23   tl    109
# 800   Fri Feb 05 09:47:49 +0000 2010         13        8   en    658
# 970   Wed Jan 27 19:53:03 +0000 2010        891     2695   en   9018
# 1074  Wed Mar 14 11:28:40 +0000 2018          8      113   in     12
# 1101  Wed Jan 27 19:53:03 +0000 2010        891     2695   en   9019
# 1368  Mon Jan 04 09:40:45 +0000 2010        958       77   en   4132
# 2175  Wed Nov 26 17:31:47 +0000 2014         48      437   pl    309
# ...

# %%
newTweets.plot()
# Out:
# country
# Australia                      AxesSubplot(0.125,0.125;0.775x0.755)
# Bahrain                        AxesSubplot(0.125,0.125;0.775x0.755)
# India                          AxesSubplot(0.125,0.125;0.775x0.755)
# Kingdom of Saudi Arabia        AxesSubplot(0.125,0.125;0.775x0.755)
# Malaysia                       AxesSubplot(0.125,0.125;0.775x0.755)
# Pakistan                       AxesSubplot(0.125,0.125;0.775x0.755)
# Republic of the Philippines    AxesSubplot(0.125,0.125;0.775x0.755)
# Russia                         AxesSubplot(0.125,0.125;0.775x0.755)
# Singapore                      AxesSubplot(0.125,0.125;0.775x0.755)
# South Africa                   AxesSubplot(0.125,0.125;0.775x0.755)
# United Arab Emirates           AxesSubplot(0.125,0.125;0.775x0.755)
# United Kingdom                 AxesSubplot(0.125,0.125;0.775x0.755)
# United States                  AxesSubplot(0.125,0.125;0.775x0.755)
# Zimbabwe                       AxesSubplot(0.125,0.125;0.775x0.755)
# ...

# %% [markdown]
# Graph shows x as number of tweets and y as Activity. This shows tweets from India and Pakistan had the most activity in them as the graph spikes here and there.

# %%
tweets_by_lang = tweets['source'].value_counts()

fig, ax = plt.subplots()
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=10)
ax.set_xlabel('Device', fontsize=15)
ax.set_ylabel('Number of tweets' , fontsize=15)
ax.set_title('Top 5 Devices', fontsize=15, fontweight='bold')
tweets_by_lang[:5].plot(ax=ax, kind='bar', color='red')

# %% [markdown]
# Following are the top 5 devices or platforms from where tweets were made. Android showed the most activity and tweets synced from facebook the least

# %% [markdown]
# TIME SERIES ANALYSIS

# %% [markdown]
# Let's visualize our statuses and likes over time

# %%
type(tweets.createdAt[0])
from datetime import datetime
tweets['date'] = tweets['createdAt'].apply(lambda x: datetime.strptime(x, '%a %b %d %H:%M:%S +0000 %Y').replace(tzinfo=pytz.UTC))

# %%
statusplot = pd.Series(data=tweets['statuses'].values, index=tweets['date'])
statusplot.plot(figsize=(16,4), color='r', label = "Statuses", legend = True);

# %%
tfav = pd.Series(data=tweets['likes'].values, index=tweets['date'])
tfav.plot(figsize=(16,4), label="Likes", legend=True)

# %%
tfav = pd.Series(data=tweets['friends'].values, index=tweets['date'])
tfav.plot(figsize=(16,4), color = 'g', label="friends", legend=True)

# %% [markdown]
# We can see that number of friends of people increased as they tweeted more and more about IPL or PSL. This shows that people started to befriend each other because of their similar interests

# %%
type(tweets.date[0])
tweets.index
tweets.set_index("date", inplace = True)
tweets["2018-03"].statuses.plot()

# %% [markdown]
# We created our index to be date then outputted our statuses generated in a single month. This also shows that the semi finals of PSL 3 had a large amount of excitement generated after their matches. And also that on 14th March, Quetta vs Lahore match had also created much excitement. As well as Multan vs Peshawar on 6th March and Lahore vs Karachi on 11th March

# %%
tweets["2018-03"].likes.plot()

# %% [markdown]
# This uses user interaction with generated statuses of following dates

# %%
tweets["2018-01":"2018-03"].statuses.plot()

# %% [markdown]
# DATA COMPARISON

# %%
import re
def word_in_text(word, text):
    word = word.lower()
    text = text.lower()
    match = re.search(word, text)
    if match:
        return True
    return False

tweets['ipl'] = tweets['text'].apply(lambda tweet: word_in_text('ipl', tweet))
tweets['psl'] = tweets['text'].apply(lambda tweet: word_in_text('psl', tweet))

# %%
prg_langs = ['ipl', 'psl']
tweets_by_prg_lang = [tweets['ipl'].value_counts()[True], tweets['psl'].value_counts()[True]]

x_pos = list(range(len(prg_langs)))
width = 0.8
fig, ax = plt.subplots()
plt.bar(x_pos, tweets_by_prg_lang, width, alpha=1, color='g')

# Setting axis labels and ticks
ax.set_ylabel('Number of tweets', fontsize=15)
ax.set_title('Ranking: ipl vs. psl  (Raw data)', fontsize=10, fontweight='bold')
ax.set_xticks([p + 0.4 * width for p in x_pos])
ax.set_xticklabels(prg_langs)
plt.grid()

# %%
tweets['cricket'] = tweets['text'].apply(lambda tweet: word_in_text('cricket', tweet))
tweets['afridi'] = tweets['text'].apply(lambda tweet: word_in_text('shahid afridi', tweet))
tweets['sammy'] = tweets['text'].apply(lambda tweet: word_in_text('sammy', tweet))
tweets['sl'] = tweets['text'].apply(lambda tweet: word_in_text('super league', tweet))
tweets['zalmi'] = tweets['text'].apply(lambda tweet: word_in_text('islamabad united', tweet))
tweets['gladiators'] = tweets['text'].apply(lambda tweet: word_in_text('pslfinalinkarachi', tweet))


print tweets['sl'].value_counts()[True]
print tweets['zalmi'].value_counts()[True]
tweets['relevant'] = tweets['text'].apply(lambda tweet: word_in_text('cricket', tweet) or word_in_text('shahid afridi', tweet) or word_in_text('super league', tweet) or word_in_text('darren sammy', tweet))

a# print("comparision:")
# print tweets[tweets['relevant'] == True]['sammy'].value_counts()[True]
# print tweets[tweets['relevant'] == True]['afridi'].value_counts()[True]
# print tweets[tweets['relevant'] == True]['cricket'].value_counts()[True]

prg_langs = ['Akmal', 'Sammy']
tweets_by_prg_lang = [tweets['sammy'].value_counts()[True], tweets['sl'].value_counts()[True]]

x_pos = list(range(len(prg_langs)))
width = 0.8
fig, ax = plt.subplots()
plt.bar(x_pos, tweets_by_prg_lang, width, alpha=1, color='g')

# Setting axis labels and ticks
ax.set_ylabel('Number of tweets', fontsize=15)
ax.set_title('Ranking: ipl vs. psl  (Raw data)', fontsize=10, fontweight='bold')
ax.set_xticks([p + 0.4 * width for p in x_pos])
ax.set_xticklabels(prg_langs)
plt.grid()
# Out:
# 143
# 220
# 96

# %% [markdown]
# SENTIMENT ANALYSIS

# %%
from textblob import TextBlob
import re

def clean_tweet(tweet):
    '''
    Utility function to clean the text in a tweet by removing 
    links and special characters using regex.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def analize_sentiment(tweet):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1

# %%
tweets['SA'] = np.array([ analize_sentiment(tweet) for tweet in tweets['text'] ])

# We display the updated dataframe with the new column:
display(tweets.head(10))
# Out:
#                            likes  friends  followers  statuses  \
# date
# 2014-06-18 20:48:43+00:00   1176      252         24      1337
# 2011-10-14 09:31:05+00:00  64060     1238        635      8049
# 2017-04-11 22:11:27+00:00     27      353         52      5472
# 2017-02-22 21:50:07+00:00  30144     1721       2489     10433
# 2014-08-17 08:39:38+00:00  18144      118        305      7304
# 2015-05-28 16:01:12+00:00  10093      316        322     13922
# 2011-05-03 12:42:49+00:00  17611      340       4428     20080
# 2011-10-27 17:21:51+00:00     89       77         35       334
# 2017-08-07 04:31:57+00:00  38677     1157        623     26219
# 2018-02-27 11:08:40+00:00   2950     1084        238      2803
#
#                                                 createdAt  \
# date
# 2014-06-18 20:48:43+00:00  Wed Jun 18 20:48:43 +0000 2014
# 2011-10-14 09:31:05+00:00  Fri Oct 14 09:31:05 +0000 2011
# 2017-04-11 22:11:27+00:00  Tue Apr 11 22:11:27 +0000 2017
# ...

# %%
pos_tweets = [ tweet for index, tweet in enumerate(tweets['text']) if tweets['SA'][index] > 0]
neu_tweets = [ tweet for index, tweet in enumerate(tweets['text']) if tweets['SA'][index] == 0]
neg_tweets = [ tweet for index, tweet in enumerate(tweets['text']) if tweets['SA'][index] < 0]

print("Percentage of positive tweets: {}%".format(len(pos_tweets)*100/len(tweets['text'])))
print("Percentage of neutral tweets: {}%".format(len(neu_tweets)*100/len(tweets['text'])))
print("Percentage de negative tweets: {}%".format(len(neg_tweets)*100/len(tweets['text'])))
# Out:
# Percentage of positive tweets: 40%
# Percentage of neutral tweets: 53%
# Percentage de negative tweets: 5%
